# %% [markdown]
# ## Welcome to the second Lab week1 Day 3 - Foundations of Agents
# We're comparing the capabilities of different models, and learning how to use the OpenAI API to interact with them. This is the foundation for all future labs, so make sure you understand this well. The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI.

# %%
import os
import json
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display
from dotenv import load_dotenv

# %%
load_dotenv(override=True) # override is True to ensure that the .env file values take precedence over any existing environment variables)
# Out:
# True

# %%
openai_api_key = os.getenv("OPENAI_API_KEY")
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")
google_api_key = os.getenv("GOOGLE_API_KEY")

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI

# %%
request = "Please come up with a challenge question about day trading that I can ask a number of LLMs to evaluate their intelligence and capabilities."
request += "Only return the question, nothing else" 
messages = [
    {"role": "user", "content": request}
]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
  model="gpt-4o-mini", 
  messages=messages
)

question = response.choices[0].message.content
display(Markdown(f"**Challenge Question:** {question}"))
# Out:
# **Challenge Question:** What strategies can traders use to manage risk effectively while maximizing their potential returns in volatile markets?

# %%
competitors = []
answers = []
messages = [
    {"role": "user", "content": f"Here is a challenge question: {question}."}
]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# start with OpenAI gpt-5-nano or 4o. 
model_name = "gpt-5-nano"
response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content
display(Markdown(answer))
answers.append({"model": model_name, "answer": answer})
competitors.append(model_name)
# Out:
# Here’s a practical, generally applicable framework traders can use to manage risk in volatile markets while still aiming for attractive returns. It’s not personalized financial advice, but it covers widely taught principles and common techniques.
#
# Core principles
# - Define your edge and limits: know your market niche, how you expect to make money, and the maximum loss you’re willing to endure in a trade or in a session.
# - Preserve capital first: risk management is about staying in the game long enough to let your edge play out.
# - Adapt to regime but stay disciplined: volatility is a feature, not a bug—adjust position sizes and strategies to market conditions, but keep core rules intact.
#
# Risk management toolkit
# - Position sizing and risk per trade
#   - Decide how much of your capital you’re willing to risk on a single trade (e.g., 0.5–2% of your account).
# ...

# %%
# Anthropic has a slightly different API, and Max Tokens is required
import anthropic


claude = Anthropic()
model_name = "claude-sonnet-4-5"

response = claude.messages.create(
    model=model_name,
    messages=messages,
    max_tokens=1000
)
answer = response.content[0].text
display(Markdown(answer))
answers.append({"model": model_name, "answer": answer})
competitors.append(model_name)
# Out:
# # Risk Management Strategies for Volatile Markets
#
# ## 1. **Position Sizing & Capital Allocation**
# - **Never risk more than 1-2% per trade** of total capital
# - Use the Kelly Criterion for optimal position sizing
# - Scale positions based on conviction and volatility levels
# - Diversify across uncorrelated assets (typically 8-15 positions)
#
# ## 2. **Stop-Loss Strategies**
# - **Volatility-adjusted stops**: Use ATR (Average True Range) multiples instead of fixed percentages
# - **Time stops**: Exit if thesis doesn't play out within expected timeframe
# - **Trailing stops**: Lock in profits as positions move favorably
# - **Mental stops**: Pre-define exit points before entering trades
#
# ## 3. **Hedging Techniques**
# - **Options strategies**: Protective puts, collars, or iron condors
# - **Inverse positions**: Hold offsetting positions in negatively correlated assets
# - **Portfolio hedging**: Use index puts or VIX calls during high uncertainty
# ...

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Navigating volatile markets is a high-wire act for traders, demanding a sophisticated blend of astute risk management and opportunistic strategy. The key isn't to eliminate risk entirely, but to understand, quantify, and control it while positioning oneself to capitalize on outsized movements.
#
# Here's a comprehensive breakdown of strategies:
#
# ---
#
# ### **I. The Foundational Pillars (Always Essential, Amplified in Volatility)**
#
# 1.  **Develop a Robust Trading Plan:**
#     *   **Define Entry Criteria:** What signals trigger a trade?
#     *   **Define Exit Criteria:** Clear profit targets (take-profit levels) and maximum loss points (stop-loss levels).
#     *   **Position Sizing Rules:** Crucial for risk management (covered below).
#     *   **Risk-Reward Ratio:** Only take trades with a favorable risk-reward, e.g., aiming for 2-3 times the potential loss.
# ...

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# ...

# %%
ollama  = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")
model_name = "llama3.2"
response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content
display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# To manage risk effectively while maximizing potential returns in volatile markets, traders can employ a variety of strategies. Here are some of the most effective ones:
#
# 1. **Position Sizing**: This involves adjusting the size of your trade based on your overall risk tolerance and potential return. A common strategy is to use a percentage of your account equity to allocate to each trade, with a maximum of 2-3% per trade.
# 2. **Stop-Loss Orders**: A stop-loss order is a type of order that automatically closes a trade if the price moves against you, limiting your potential loss. This can help you avoid significant losses and prevent emotional decision-making.
# 3. **Risk-Reward Ratio**: This involves setting a risk-reward ratio that determines how much you are willing to risk in pursuit of a potential return. For example, you may set a risk-reward ratio of 1:2, meaning you're willing to risk $1 to potentially win $2.
# ...

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'claude-sonnet-4-5', 'gemini-2.5-flash', 'llama3.2']
# ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# ...

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    competitor_name = competitors[index] if index < len(competitors) else f"competitor {index+1}"
    together += f"# Response from {competitor_name}\n\n"
    
    if isinstance(answer, dict):
        answer_text = str(answer.get("answer", ""))
    else:
        answer_text = str(answer)
    
    together += answer_text + "\n\n"

# %%
print(together)
# Out:
# # Response from gpt-5-nano
#
# Here’s a practical, generally applicable framework traders can use to manage risk in volatile markets while still aiming for attractive returns. It’s not personalized financial advice, but it covers widely taught principles and common techniques.
#
# Core principles
# - Define your edge and limits: know your market niche, how you expect to make money, and the maximum loss you’re willing to endure in a trade or in a session.
# - Preserve capital first: risk management is about staying in the game long enough to let your edge play out.
# - Adapt to regime but stay disciplined: volatility is a feature, not a bug—adjust position sizes and strategies to market conditions, but keep core rules intact.
#
# Risk management toolkit
# - Position sizing and risk per trade
#   - Decide how much of your capital you’re willing to risk on a single trade (e.g., 0.5–2% of your account).
# ...

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 4 competitors.
# Each model has been given this question:
#
# What strategies can traders use to manage risk effectively while maximizing their potential returns in volatile markets?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from gpt-5-nano
#
# Here’s a practical, generally applicable framework traders can use to manage risk in volatile markets while still aiming for attractive returns. It’s not personalized financial advice, but it covers widely taught principles and common techniques.
#
# Core principles
# ...

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["3", "1", "2", "4"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemini-2.5-flash
# Rank 2: gpt-5-nano
# Rank 3: claude-sonnet-4-5
# Rank 4: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### In my opinion I used parallization agregation:
# -  I have coordinator llm which is gpt-5-nano generate a question.
# - Then that question is parralelly passed to different llms to generate their own outputs.
# - their outputs are then agregated together and passed to the judge llm which is gpt-5-nano to determine the best answer.
