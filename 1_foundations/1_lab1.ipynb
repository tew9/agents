# %%
# first lets import our environment variables


from dotenv import load_dotenv

# next we will load the api keys into the enviroment and override any globally set key

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %%
#Check the key for whichever model provider you're using, except ollama which doesn't need a key
import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"openai keye exists and begin with {openai_api_key[:8]}")
else:
    print("Key doesn't exist - please head to the troubleshooting section and find out why")
# Out:
# openai keye exists and begin with sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why
from openai import OpenAI

#create an instance of OpenAI class
openai = OpenAI()

# %%
message = [{"role": "user", "content": "what is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=message)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# If you have a 3-liter jug and a 5-liter jug, and you need to measure out exactly 4 liters of water using only these jugs, how can you do it? Describe the steps clearly.

# %%
# use gpt generated question to as the user question and ask for an answer:
# form a new messages list

messages = [{"role": "user", "content": question}]
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Here's how to measure exactly 4 liters using a 3-liter jug and a 5-liter jug:
#
# ### Initial conditions:
# - 3-liter jug (empty)
# - 5-liter jug (empty)
# - Unlimited water supply
#
# ### Goal:
# Measure exactly **4 liters** in the 5-liter jug.
#
# ---
#
# ### Steps:
#
# 1. **Fill the 5-liter jug completely.**
#    (5-liter jug: 5 liters, 3-liter jug: 0 liters)
#
# 2. **Pour water from the 5-liter jug into the 3-liter jug until the 3-liter jug is full.**
#    - Transfer 3 liters from the 5-liter jug to the 3-liter jug.
#    (5-liter jug: 2 liters left, 3-liter jug: 3 liters)
#
# 3. **Empty the 3-liter jug.**
#    (5-liter jug: 2 liters, 3-liter jug: 0 liters)
#
# 4. **Pour the remaining 2 liters from the 5-liter jug into the 3-liter jug.**
#    (5-liter jug: 0 liters, 3-liter jug: 2 liters)
#
# 5. **Fill the 5-liter jug completely again.**
#    (5-liter jug: 5 liters, 3-liter jug: 2 liters)
#
# ...

# %%
# First create the messages:

messages = [{"role": "user", "content": "create a business idea for a startup that combines AI and fitness"}]

# Then make the first call:

response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message
messages = [
    {"role": "user", "content": f"Here is a business idea: {business_idea}. Please now create a catchy name for this business idea."}
]

response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
business_name = response.choices[0].message.content

display(Markdown(f"**Business Idea:** {business_idea}"))
display(Markdown(f"**Business Name:** {business_name}"))
# Out:
# **Business Idea:** Certainly! Here's a startup idea that combines AI and fitness:
#
# **Startup Name:** FitSense AI
#
# **Concept:**
# FitSense AI is a personalized fitness coaching platform that leverages advanced AI to create dynamic, adaptive workout and nutrition plans tailored in real-time to each user's unique physiology, goals, and lifestyle. Using data from wearable devices, user feedback, and environmental factors, FitSense AI ensures optimal performance, injury prevention, and sustainable progress.
#
# **Key Features:**
#
# 1. **Real-Time Adaptive Workouts:**
#    AI algorithms analyze data from smartwatches, heart rate monitors, sleep trackers, and motion sensors to adjust workout intensity, duration, and exercises on the fly. For example, if the user’s heart rate variability suggests fatigue, the app automatically suggests a lighter workout or rest day.
#
# 2. **Personalized Nutrition Guidance:**
# ...
